# %%
import numpy as np
import pandas as pd
import shap
from sklearn.impute import KNNImputer
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from econml.grf import CausalForest

from matplotlib import pyplot as plt

# %%
data = pd.read_csv("bsc_project_set.csv", index_col=0)

xs = data.copy()

y = xs["mort_28"]
w = xs["peep_regime"]

w = pd.Series(map(lambda x: 0 if x == "low" else 1, w))
y = pd.Series(map(lambda x: 1 if x == False else 0, y))

xs = xs.drop(columns=["id", "mort_28", "peep", "peep_regime"])
columns_x = xs.columns

xs.loc[xs["sex"] == "M", "sex"] = 0
xs.loc[xs["sex"] == "F", "sex"] = 1

norm_xs = (xs - xs.mean())/xs.std()

imputer = KNNImputer(n_neighbors=2, weights="uniform")
imp_xs = imputer.fit_transform(norm_xs)

imp_xs = pd.DataFrame(data=imp_xs, columns=columns_x)

imp_xs
# Out:
#            age       sex    weight    height  pf_ratio       po2      pco2  \
# 0     0.732971  1.191182  0.183841 -0.123443 -0.026374 -0.049713 -1.422636
# 1    -1.005004 -0.839289  1.422974  1.198448 -0.637005 -0.385550 -0.768253
# 2     1.353676 -0.839289 -0.381057  0.052809 -0.171336 -0.406111 -0.403630
# 3     1.353676 -0.839289  0.100018  0.052809 -0.319055 -1.169822 -0.403630
# 4     0.050195 -0.839289 -0.654395  1.198448 -0.577049 -0.737052 -0.334933
# ...        ...       ...       ...       ...       ...       ...       ...
# 3936  0.919183  1.191182 -1.128181 -0.828452 -0.711144  0.068026 -0.395043
# 3937  0.732971 -0.839289  0.475402  0.757817 -0.527518 -0.793421 -0.300585
# 3938  0.236407  1.191182  0.438957 -0.387822 -0.701828 -0.554080  0.137359
# 3939  0.298477 -0.839289  0.245798 -0.564074 -0.425805 -0.814696 -0.156321
# 3940 -0.322228 -0.839289 -0.381057  0.757817 -0.715198 -0.259733 -0.403630
#
#             ph  driving_pressure  lung_compliance  ...  platelets      urea  \
# 0    -1.225725         -0.364306        -0.580942  ...  -1.048713 -0.897592
# 1    -1.823462         -1.141620         1.996152  ...  -1.629822  2.693985
# 2     1.164175          1.468983        -0.468897  ...  -0.668334  0.703662
# 3     1.901629          1.395651        -0.811559  ...   0.023680  1.738181
# 4     0.672538         -1.072479         0.565211  ...   2.898673 -0.720674
# ...        ...               ...              ...  ...        ...       ...
# 3936  0.314053          1.219655        -0.814377  ...   0.112283  0.478767
# 3937 -0.433644         -0.540301         0.012723  ...  -1.092709  2.250942
# 3938 -0.648735          0.281012        -0.869185  ...   1.026414  0.532742
# 3939  0.844611          0.075683        -0.444100  ...  -0.423609 -0.522017
# 3940  1.737750          0.222346         0.450237  ...   0.601123 -0.398324
#
#           fio2      hco3  heart_rate  minute_volume  plateau_pressure  \
# 0    -0.564826 -1.945761    1.474415      -0.543738          0.705302
# 1     0.758913 -1.800247    1.474372       3.032717         -0.620678
# 2    -0.434729  0.188444   -1.071592      -0.035368          0.317210
# 3    -1.503965  0.964519   -1.046993      -0.868889          0.640620
# 4    -0.385943 -0.070247   -0.851941      -1.051634         -1.236080
# ...        ...       ...         ...            ...               ...
# 3936  0.541000 -0.005574    0.373186      -0.428608          0.252528
# 3937 -0.411497 -0.859256   -1.612986      -0.966353         -1.028174
# 3938  1.377339 -0.626434    1.846693      -0.299739          1.869576
# 3939  0.150708  0.285454   -1.309207      -0.298318          0.113924
# 3940  0.205750  0.964519   -0.250825       0.242810         -0.640082
#
#       respiratory_rate  syst_blood_pressure  diastolic_blood_pressure
# 0            -0.416477            -0.675390                  0.464621
# 1            -0.199109            -0.769333                  0.447981
# 2            -1.156597            -0.593191                 -1.354663
# 3            -0.593435            -0.236013                 -1.365063
# 4            -1.350927            -0.510105                 -0.435811
# ...                ...                  ...                       ...
# 3936         -0.955742            -0.205677                 -0.683525
# 3937         -0.927655            -0.702715                 -0.705604
# 3938          1.093747            -0.605551                 -0.248263
# 3939          0.199255             2.694801                  1.737565
# 3940         -0.862380            -0.438399                 -0.361318
#
# [3941 rows x 23 columns]

# %%
full_data = imp_xs.assign(W=w, Y=y)

# %%
train, test = train_test_split(full_data, test_size=0.3)
train_x = train[columns_x]
test_x = test[columns_x]

# %%
# S-learner
regr_s = RandomForestRegressor()
regr_s.fit(train.drop(columns=["Y"]), train["Y"])

# T-learner
regr0_t = RandomForestRegressor()
regr1_t = RandomForestRegressor()
regr0_t.fit(train.query("W==0").drop(columns=["W", "Y"]), train.query("W==0")["Y"])
regr1_t.fit(train.query("W==1").drop(columns=["W", "Y"]), train.query("W==1")["Y"])

# Causal forest
causal_forest = CausalForest()
causal_forest.fit(X=train_x, T=train["W"], y=train["Y"])
# Out:
# CausalForest()

# %% [markdown]
# # S-learner

# %%
explainer_s = shap.Explainer(regr_s)
shap_values_s = explainer_s(imp_xs)
shap.plots.bar(shap_values_s, max_display=24)
# Out:
# ---------------------------------------------------------------------------
# ExplainerError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 explainer_s = shap.Explainer(regr_s)
# ----> 2 shap_values_s = explainer_s(imp_xs)
#       3 shap.plots.bar(shap_values_s, max_display=24)
#
# File D:\Delft\Year 3\Q4\code\research-project\venv\Lib\site-packages\shap\explainers\_tree.py:233, in TreeExplainer.__call__(self, X, y, interactions, check_additivity)
#     230     feature_names = getattr(self, "data_feature_names", None)
#     232 if not interactions:
# --> 233     v = self.shap_values(X, y=y, from_call=True, check_additivity=check_additivity, approximate=self.approximate)
#     234     if isinstance(v, list):
#     235         v = np.stack(v, axis=-1)  # put outputs at the end
#
# File D:\Delft\Year 3\Q4\code\research-project\venv\Lib\site-packages\shap\explainers\_tree.py:446, in TreeExplainer.shap_values(self, X, y, tree_limit, approximate, check_additivity, from_call)
#     444 out = self._get_shap_output(phi, flat_output)
#     445 if check_additivity and self.model.model_output == "raw":
# --> 446     self.assert_additivity(out, self.model.predict(X))
#     448 return out
#
# File D:\Delft\Year 3\Q4\code\research-project\venv\Lib\site-packages\shap\explainers\_tree.py:579, in TreeExplainer.assert_additivity(self, phi, model_output)
#     577         check_sum(self.expected_value[i] + phi[i].sum(-1), model_output[:,i])
#     578 else:
# --> 579     check_sum(self.expected_value + phi.sum(-1), model_output)
#
# File D:\Delft\Year 3\Q4\code\research-project\venv\Lib\site-packages\shap\explainers\_tree.py:573, in TreeExplainer.assert_additivity.<locals>.check_sum(sum_val, model_output)
#     569     err_msg += " Consider retrying with the feature_perturbation='interventional' option."
#     570 err_msg += " This check failed because for one of the samples the sum of the SHAP values" \
#     571            " was {:f}, while the model output was {:f}. If this difference is acceptable" \
#     572            " you can set check_additivity=False to disable this check.".format(sum_val[ind], model_output[ind])
# --> 573 raise ExplainerError(err_msg)
#
# ExplainerError: Additivity check failed in TreeExplainer! Please ensure the data matrix you passed to the explainer is the same shape that the model was trained on. If your data shape is correct then please report this on GitHub. Consider retrying with the feature_perturbation='interventional' option. This check failed because for one of the samples the sum of the SHAP values was 0.326875, while the model output was 0.240000. If this difference is acceptable you can set check_additivity=False to disable this check.

# %% [markdown]
# # T-leaner

# %%
explainer_t = shap.Explainer(model=(lambda xs: regr1_t.predict(xs) - regr0_t.predict(xs)), masker=shap.utils.sample(train_x, 100))
shap_values_t = explainer_t(imp_xs)
shap.plots.bar(shap_values_t, max_display=24)
# Out:
# PermutationExplainer explainer:   8%|▊         | 308/3941 [02:25<30:40,  1.97it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14252\1136669798.py in ?()
#       1 explainer_t = shap.Explainer(model=(lambda xs: regr1_t.predict(xs) - regr0_t.predict(xs)), masker=shap.utils.sample(train_x, 100))
# ----> 2 shap_values_t = explainer_t(imp_xs)
#       3 shap.plots.bar(shap_values_t, max_display=24)
#
# D:\Delft\Year 3\Q4\code\research-project\venv\Lib\site-packages\shap\explainers\_permutation.py in ?(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args)
#      75     def __call__(self, *args, max_evals=500, main_effects=False, error_bounds=False, batch_size="auto",
#      76                  outputs=None, silent=False):
#      77         """ Explain the output of the model on the given arguments.
#      78         """
# ---> 79         return super().__call__(
#      80             *args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds, batch_size=batch_size,
#      81             outputs=outputs, silent=silent
#      82         )
#
# D:\Delft\Year 3\Q4\code\research-project\venv\Lib\site-packages\shap\explainers\_explainer.py in ?(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args, **kwargs)
#     260         error_std = []
#     261         if callable(getattr(self.masker, "feature_names", None)):
#     262             feature_names = [[] for _ in range(len(args))]
#     263         for row_args in show_progress(zip(*args), num_rows, self.__class__.__name__+" explainer", silent):
# --> 264             row_result = self.explain_row(
#     265                 *row_args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds,
#     266                 batch_size=batch_size, outputs=outputs, silent=silent, **kwargs
#     267             )
#
# D:\Delft\Year 3\Q4\code\research-project\venv\Lib\site-packages\shap\explainers\_permutation.py in ?(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *row_args)
#     163             expected_value = outputs[0]
#     164
#     165             # compute the main effects if we need to
#     166             if main_effects:
# --> 167                 main_effect_values = fm.main_effects(inds, batch_size=batch_size)
#     168         else:
#     169             masks = np.zeros(1, dtype=int)
#     170             outputs = fm(masks, zero_index=0, batch_size=1)
#
# D:\Delft\Year 3\Q4\code\research-project\venv\Lib\site-packages\shap\utils\_masked_model.py in ?(self, inds, batch_size)
#     255             masks[2*i+1] = inds[i] # turn on this input
#     256             last_ind = inds[i]
#     257
#     258         # compute the main effects for the given indexes
# --> 259         outputs = self(masks, batch_size=batch_size)
#     260         main_effects = outputs[1:] - outputs[0]
#     261
#     262         # expand the vector to the full input size
#
# D:\Delft\Year 3\Q4\code\research-project\venv\Lib\site-packages\shap\utils\_masked_model.py in ?(self, masks, zero_index, batch_size)
#      55
#      56         # if we are passed a 1D array of indexes then we are delta masking and have a special implementation
#      57         if len(masks.shape) == 1:
#      58             if getattr(self.masker, "supports_delta_masking", False):
# ---> 59                 return self._delta_masking_call(masks, zero_index=zero_index, batch_size=batch_size)
#      60
#      61             # we need to convert from delta masking to a full masking call because we were given a delta masking
#      62             # input but the masker does not support delta masking
#
# D:\Delft\Year 3\Q4\code\research-project\venv\Lib\site-packages\shap\utils\_masked_model.py in ?(self, masks, zero_index, batch_size)
#     201         for i in range(len(varying_rows)):
#     202             batch_positions[i+1] = batch_positions[i] + num_varying_rows[i]
#     203
#     204         # joined_masked_inputs = self._stack_inputs(all_masked_inputs)
# --> 205         outputs = self.model(*subset_masked_inputs)
#     206         _assert_output_input_match(subset_masked_inputs, outputs)
#     207
#     208         if self.linearize_link and self.link != links.identity and self._linearizing_weights is None:
#
# D:\Delft\Year 3\Q4\code\research-project\venv\Lib\site-packages\shap\models\_model.py in ?(self, *args)
#      27     def __call__(self, *args):
# ---> 28         out = self.inner_model(*args)
#      29         is_tensor = safe_isinstance(out, "torch.Tensor")
#      30         out = out.cpu().detach().numpy() if is_tensor else np.array(out)
#      31         return out
#
# ~\AppData\Local\Temp\ipykernel_14252\1136669798.py in ?(xs)
# ----> 1 explainer_t = shap.Explainer(model=(lambda xs: regr1_t.predict(xs) - regr0_t.predict(xs)), masker=shap.utils.sample(train_x, 100))
#
# D:\Delft\Year 3\Q4\code\research-project\venv\Lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X)
#    1060             The predicted values.
#    1061         """
#    1062         check_is_fitted(self)
#    1063         # Check data
# -> 1064         X = self._validate_X_predict(X)
#    1065
#    1066         # Assign chunk of trees to jobs
#    1067         n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# D:\Delft\Year 3\Q4\code\research-project\venv\Lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X)
#     637             force_all_finite = "allow-nan"
#     638         else:
#     639             force_all_finite = True
#     640
# --> 641         X = self._validate_data(
#     642             X,
#     643             dtype=DTYPE,
#     644             accept_sparse="csr",
#
# D:\Delft\Year 3\Q4\code\research-project\venv\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     629                 out = y
#     630             else:
#     631                 out = X, y
#     632         elif not no_val_X and no_val_y:
# --> 633             out = check_array(X, input_name="X", **check_params)
#     634         elif no_val_X and not no_val_y:
#     635             out = _check_y(y, **check_params)
#     636         else:
#
# D:\Delft\Year 3\Q4\code\research-project\venv\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     994                         )
#     995                     array = xp.astype(array, dtype, copy=False)
#     996                 else:
#     997                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# --> 998             except ComplexWarning as complex_warning:
#     999                 raise ValueError(
#    1000                     "Complex data not supported\n{}\n".format(array)
#    1001                 ) from complex_warning
#
# D:\Delft\Year 3\Q4\code\research-project\venv\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp)
#     517         # Use NumPy API to support order
#     518         if copy is True:
#     519             array = numpy.array(array, order=order, dtype=dtype)
#     520         else:
# --> 521             array = numpy.asarray(array, order=order, dtype=dtype)
#     522
#     523         # At this point array is a NumPy ndarray. We convert it to an array
#     524         # container that is consistent with the input's namespace.
#
# D:\Delft\Year 3\Q4\code\research-project\venv\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# KeyboardInterrupt:

# %% [markdown]
# # Causal Forest

# %%
explainer_forest = shap.Explainer(causal_forest.predict, shap.utils.sample(train_x, 100))
shap_values_forest = explainer_forest(imp_xs)
shap.plots.bar(shap_values_forest, max_display=23)
# Out:
# PermutationExplainer explainer: 3942it [27:55,  2.34it/s]

# %%
shap.plots.beeswarm(shap_values_forest, max_display=23)
